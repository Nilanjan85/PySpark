# %% [markdown]
# Basics Of Pyspark RDD

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.3 MB 45 kB/s
# ...
#      |████████████████████████████████| 199 kB 41.4 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=683fc4c3d77a67f266ba04f9793cf4ff76039ab5ed78f4b17a3b6f8cef37180f
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('RDD basic').getOrCreate()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dd05b1b2-0803-44c0-b522-619b79fff712" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd05b1b2-0803-44c0-b522-619b79fff712">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving appl_stock.csv to appl_stock.csv

# %%
from pyspark import SparkContext

# %%
sc = SparkContext.getOrCreate()

# %%
myRdd = sc.parallelize([1,2,5,7,9,10,34])

# %%
myRdd.sum()
# Out:
# 68

# %%
x = sc.parallelize(['A','A','B'])
y = x.distinct()

# %%
print(x.collect())
print(y.collect())
# Out:
# ['A', 'A', 'B']
# ['A', 'B']

# %%
type(x)
# Out:
# pyspark.rdd.RDD

# %% [markdown]
# To get access to all the methods of RDD

# %%
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_computeFractionForSampleSize',
#  '_defaultReducePartitions',
#  '_id',
#  '_is_barrier',
#  '_jrdd',
#  '_jrdd_deserializer',
#  '_memory_limit',
#  '_pickled',
#  '_reserialize',
#  '_to_java_object_rdd',
#  'aggregate',
#  'aggregateByKey',
#  'barrier',
#  'cache',
#  'cartesian',
#  'checkpoint',
#  'cleanShuffleDependencies',
#  'coalesce',
#  'cogroup',
#  'collect',
#  'collectAsMap',
#  'collectWithJobGroup',
#  'combineByKey',
#  'context',
# ...

# %% [markdown]
# Help function is used to give details of a function

# %%
#help(x)

# %%
stock_rdd = sc.textFile('appl_stock.csv')
stock_rdd.collect()
# Out:
# ['Date,Open,High,Low,Close,Volume,Adj Close',
#  '2010-01-04,213.429998,214.499996,212.38000099999996,214.009998,123432400,27.727039',
#  '2010-01-05,214.599998,215.589994,213.249994,214.379993,150476200,27.774976000000002',
#  '2010-01-06,214.379993,215.23,210.750004,210.969995,138040000,27.333178000000004',
#  '2010-01-07,211.75,212.000006,209.050005,210.58,119282800,27.28265',
#  '2010-01-08,210.299994,212.000006,209.06000500000002,211.98000499999998,111902700,27.464034',
#  '2010-01-11,212.79999700000002,213.000002,208.450005,210.11000299999998,115557400,27.221758',
#  '2010-01-12,209.18999499999998,209.76999500000002,206.419998,207.720001,148614900,26.91211',
#  '2010-01-13,207.870005,210.92999500000002,204.099998,210.650002,151473000,27.29172',
#  '2010-01-14,210.11000299999998,210.45999700000002,209.020004,209.43,108223500,27.133657',
#  '2010-01-15,210.92999500000002,211.59999700000003,205.869999,205.93,148516900,26.680197999999997',
# ...

# %%
stock_rdd.first()
# Out:
# 'Date,Open,High,Low,Close,Volume,Adj Close'

# %%
stock_rdd.take(5)
# Out:
# ['Date,Open,High,Low,Close,Volume,Adj Close',
#  '2010-01-04,213.429998,214.499996,212.38000099999996,214.009998,123432400,27.727039',
#  '2010-01-05,214.599998,215.589994,213.249994,214.379993,150476200,27.774976000000002',
#  '2010-01-06,214.379993,215.23,210.750004,210.969995,138040000,27.333178000000004',
#  '2010-01-07,211.75,212.000006,209.050005,210.58,119282800,27.28265']

# %%
myRdd.max()
# Out:
# 34

# %%
myRdd.min()
# Out:
# 1

# %%
myRdd.takeSample(True,4)
# Out:
# [10, 7, 10, 10]

# %%
myRdd.takeSample(False,4)
# Out:
# [10, 34, 2, 5]

# %%
myRdd.reduce(lambda a,b: a+b )
# Out:
# 68

# %%
new_Rdd = sc.parallelize([1,2,3,3,3,4,5,5,6,1,7])
new_Rdd.countByValue()
# Out:
# defaultdict(int, {1: 2, 2: 1, 3: 3, 4: 1, 5: 2, 6: 1, 7: 1})

# %%
new_Rdd1 = sc.parallelize([('a',2),('b',4),('c',6),('a',10)])
new_Rdd1.countByKey()
# Out:
# defaultdict(int, {'a': 2, 'b': 1, 'c': 1})
