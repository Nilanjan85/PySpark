# %%
! pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 43 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 46.4 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=730cd854ee328fc714d3093fda34bc364c92108b82daf1926da816e6fca7d67b
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.0

# %%
from pyspark.sql import SparkSession

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6147b483-8257-4ef9-8a1d-e6a9f44ae1fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6147b483-8257-4ef9-8a1d-e6a9f44ae1fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving people.json to people.json

# %%
spark = SparkSession.builder.appName("Basic").getOrCreate()

# %%
df = spark.read.json("people.json")

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.columns
# Out:
# ['age', 'name']

# %%
df.describe().show()
# Out:
# +-------+------------------+-------+
# |summary|               age|   name|
# +-------+------------------+-------+
# |  count|                 2|      3|
# |   mean|              24.5|   null|
# | stddev|7.7781745930520225|   null|
# |    min|                19|   Andy|
# |    max|                30|Michael|
# +-------+------------------+-------+

# %%
from pyspark.sql.types import StructField, StringType, IntegerType, StructType

# %%
datashema = [StructField('age',IntegerType(),True), StructField('name',StringType(),True)]

# %%
final_struct = StructType(fields=datashema)

# %%
df = spark.read.json('people.json',schema=final_struct)

# %%
df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- name: string (nullable = true)

# %%
type(df['age'])
# Out:
# pyspark.sql.column.Column

# %%
type(df.select('age'))
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.head(2)[0]
# Out:
# Row(age=None, name='Michael')

# %%
type(df.head(2)[0])
# Out:
# pyspark.sql.types.Row

# %%
## Multiple Column Select 
df.select(['age','name'])
# Out:
# DataFrame[age: int, name: string]

# %%
df.select(['age','name']).show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
# Create columns
df.withColumn('newage',df['age']*2).show() # this will only be showned but not assigned to the dataframe
# Out:
# +----+-------+------+
# | age|   name|newage|
# +----+-------+------+
# |null|Michael|  null|
# |  30|   Andy|    60|
# |  19| Justin|    38|
# +----+-------+------+

# %%
df = df.withColumn('newage',df['age']*2)

# %%
df.show()
# Out:
# +----+-------+------+
# | age|   name|newage|
# +----+-------+------+
# |null|Michael|  null|
# |  30|   Andy|    60|
# |  19| Justin|    38|
# +----+-------+------+

# %%
df = df.withColumnRenamed('newage','double_age')

# %%
df.show()
# Out:
# +----+-------+----------+
# | age|   name|double_age|
# +----+-------+----------+
# |null|Michael|      null|
# |  30|   Andy|        60|
# |  19| Justin|        38|
# +----+-------+----------+

# %%
# Pure SQL can be used 

df.createOrReplaceTempView('people')
result = spark.sql('select * from people')
result.show()
# Out:
# +----+-------+----------+
# | age|   name|double_age|
# +----+-------+----------+
# |null|Michael|      null|
# |  30|   Andy|        60|
# |  19| Justin|        38|
# +----+-------+----------+

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d56347f5-149a-48e2-965b-a301a628b9f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d56347f5-149a-48e2-965b-a301a628b9f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving appl_stock.csv to appl_stock.csv

# %%
## Spark way of tranformation 
df_stock = spark.read.csv('appl_stock.csv',header=True,inferSchema=True)
df_stock.show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04 00:00:00|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05 00:00:00|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06 00:00:00|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07 00:00:00|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# |2010-01-08 00:00:00|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# |2010-01-11 00:00:00|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# |2010-01-12 00:00:00|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# |2010-01-13 00:00:00|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# |2010-01-14 00:00:00|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# |2010-01-15 00:00:00|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# |2010-01-19 00:00:00|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# |2010-01-20 00:00:00|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# |2010-01-21 00:00:00|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# |2010-01-22 00:00:00|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# |2010-01-25 00:00:00|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# |2010-01-26 00:00:00|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# |2010-01-27 00:00:00|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# |2010-01-28 00:00:00|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# |2010-01-29 00:00:00|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# |2010-02-01 00:00:00|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %%
#Filter records
df_stock.filter("Close <= 200").show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-22 00:00:00|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# |2010-01-28 00:00:00|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# |2010-01-29 00:00:00|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# |2010-02-01 00:00:00|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# |2010-02-02 00:00:00|        195.909998|        196.319994|193.37999299999998|        195.859997|174585600|25.375532999999997|
# |2010-02-03 00:00:00|        195.169994|        200.200003|        194.420004|        199.229994|153832000|25.812148999999998|
# |2010-02-04 00:00:00|        196.730003|        198.370001|        191.570005|        192.050003|189413000|         24.881912|
# |2010-02-05 00:00:00|192.63000300000002|             196.0|        190.850002|        195.460001|212576700|25.323710000000002|
# |2010-02-08 00:00:00|        195.690006|197.88000300000002|        193.999994|194.11999699999998|119567700|           25.1501|
# |2010-02-09 00:00:00|        196.419996|        197.499994|        194.749998|196.19000400000002|158221700|         25.418289|
# |2010-02-10 00:00:00|        195.889997|             196.6|            194.26|195.12000700000002| 92590400|          25.27966|
# |2010-02-11 00:00:00|        194.880001|        199.750006|194.05999599999998|        198.669994|137586400|         25.739595|
# |2010-02-23 00:00:00|        199.999998|        201.330002|        195.709993|        197.059998|143773700|         25.531005|
# |2014-06-09 00:00:00|         92.699997|         93.879997|             91.75|         93.699997| 75415000|         88.906324|
# |2014-06-10 00:00:00|         94.730003|         95.050003|             93.57|             94.25| 62777000|         89.428189|
# |2014-06-11 00:00:00|         94.129997|         94.760002|         93.470001|         93.860001| 45681000|         89.058142|
# |2014-06-12 00:00:00|         94.040001|         94.120003|         91.900002|         92.290001| 54749000|         87.568463|
# |2014-06-13 00:00:00|         92.199997|         92.440002|         90.879997|         91.279999| 54525000|         86.610132|
# |2014-06-16 00:00:00|         91.510002|             92.75|         91.449997|         92.199997| 35561000|         87.483064|
# |2014-06-17 00:00:00|         92.309998|         92.699997|         91.800003| 92.08000200000001| 29726000| 87.36920699999999|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %%
df_stock.filter("Close<=200").select(['Date','Open','Close']).show()
# Out:
# +-------------------+------------------+------------------+
# |               Date|              Open|             Close|
# +-------------------+------------------+------------------+
# |2010-01-22 00:00:00|206.78000600000001|            197.75|
# |2010-01-28 00:00:00|        204.930004|        199.289995|
# |2010-01-29 00:00:00|        201.079996|        192.060003|
# |2010-02-01 00:00:00|192.36999699999998|        194.729998|
# |2010-02-02 00:00:00|        195.909998|        195.859997|
# |2010-02-03 00:00:00|        195.169994|        199.229994|
# |2010-02-04 00:00:00|        196.730003|        192.050003|
# |2010-02-05 00:00:00|192.63000300000002|        195.460001|
# |2010-02-08 00:00:00|        195.690006|194.11999699999998|
# |2010-02-09 00:00:00|        196.419996|196.19000400000002|
# |2010-02-10 00:00:00|        195.889997|195.12000700000002|
# |2010-02-11 00:00:00|        194.880001|        198.669994|
# |2010-02-23 00:00:00|        199.999998|        197.059998|
# |2014-06-09 00:00:00|         92.699997|         93.699997|
# |2014-06-10 00:00:00|         94.730003|             94.25|
# |2014-06-11 00:00:00|         94.129997|         93.860001|
# |2014-06-12 00:00:00|         94.040001|         92.290001|
# |2014-06-13 00:00:00|         92.199997|         91.279999|
# |2014-06-16 00:00:00|         91.510002|         92.199997|
# |2014-06-17 00:00:00|         92.309998| 92.08000200000001|
# +-------------------+------------------+------------------+
# only showing top 20 rows

# %%
df_stock.filter(df_stock['Close']>=300).select(['Open','High']).show()
# Out:
# +------------------+------------------+
# |              Open|              High|
# +------------------+------------------+
# |        300.200008|        301.959995|
# |        301.690002|        302.469994|
# |307.43998700000003|             315.0|
# |        318.470013|        319.000011|
# |303.40000200000003|        313.770012|
# |        308.999996|        314.249996|
# |312.35999300000003|314.73999399999997|
# |309.07001099999997|310.03999300000004|
# |        309.090012|        311.600002|
# |306.86998700000004|        309.740013|
# |307.65000499999996|         309.89999|
# |        307.950012|             308.0|
# |        304.230007|        305.880005|
# |302.22000099999997|305.59999799999997|
# |        307.000004|310.19001000000003|
# |311.37001000000004|        312.880005|
# |        315.449997|320.18001200000003|
# |        317.990002|319.57001099999997|
# |        317.199997|        319.769989|
# |        321.049992|        321.300011|
# +------------------+------------------+
# only showing top 20 rows

# %%
## Multiple Filter Column 
df_stock.filter((df_stock['Close']> 300) & (df_stock['Open']> 350)).show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |2011-02-08 00:00:00|        353.680004|        355.519993|        352.150009|        355.200012| 95260200|         46.019554|
# |2011-02-09 00:00:00|        355.189999|        358.999992|        354.869991|            358.16|120686300|46.403048999999996|
# |2011-02-10 00:00:00|        357.389996|        359.999989|        348.000008|        354.539997|232137500|         45.934043|
# |2011-02-11 00:00:00|        354.749989|        357.799992|353.54000099999996|         356.85001| 91893200|         46.233327|
# |2011-02-14 00:00:00|        356.790009|359.48000299999995|356.71000699999996|        359.179996| 77604100|         46.535199|
# |2011-02-15 00:00:00|359.19001000000003|359.97000099999997|        357.549999|        359.900013| 71043700|         46.628484|
# |2011-02-16 00:00:00|        360.800007|        364.899994|             360.5|        363.129993|120289400|         47.046959|
# |2011-02-17 00:00:00|        357.249992|        360.270008|        356.519989|        358.300003|132645800|         46.421188|
# |2011-02-18 00:00:00|358.70999900000004|        359.500004|        349.519989|350.56001299999997|204014300|45.418397999999996|
# |2011-02-28 00:00:00|        351.240002|        355.049995|        351.119999|353.21000699999996|100768500|          45.76173|
# |2011-03-01 00:00:00|355.47000499999996|355.71999700000003|            347.68|        349.309998|114034200|45.256446000000004|
# |2011-03-03 00:00:00|        357.189991|        359.789997|        355.920002|        359.560005|125197100|46.584433000000004|
# |2011-03-04 00:00:00|        360.070004|        360.290009|        357.750004|        359.999989|113316700|46.641436999999996|
# |2011-03-07 00:00:00|        361.399994|        361.669987|351.30998999999997|355.35998900000004|136530800|         46.040281|
# |2011-03-08 00:00:00|        354.909992|        357.400009|        352.250011|        355.759998| 89079200|         46.092106|
# |2011-03-09 00:00:00|354.68998700000003|        354.760002|        350.599987|         352.46999|113326500|45.665853999999996|
# |2011-03-14 00:00:00|        353.179993|        356.479988|351.30998999999997|        353.560001|108989300|         45.807075|
# |2011-03-28 00:00:00|353.15000499999996|        354.319992|350.44001000000003|350.44001000000003| 77338800|          45.40285|
# |2011-03-30 00:00:00|        350.639988|        350.879993|        347.439995|        348.630009| 82351500|         45.168347|
# |2011-04-01 00:00:00|        351.110012|        351.589996|        343.300007|        344.560009|104665400|44.641040000000004|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %%
df_stock.filter(df_stock['Low'] == 197.16).show()
# Out:
# +-------------------+------------------+----------+------+------+---------+---------+
# |               Date|              Open|      High|   Low| Close|   Volume|Adj Close|
# +-------------------+------------------+----------+------+------+---------+---------+
# |2010-01-22 00:00:00|206.78000600000001|207.499996|197.16|197.75|220441900|25.620401|
# +-------------------+------------------+----------+------+------+---------+---------+

# %%
result = df_stock.filter(df_stock['Low'] == 197.16).collect() ## this returns as a list objects

# %%
# convert this row list to disctionary 
type(result[0]) ## this is a row object
dic = result[0].asDict()

# %%
dic['Volume']
# Out:
# 220441900

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a4468b0-e9c8-4943-a842-97c90cb2b427" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a4468b0-e9c8-4943-a842-97c90cb2b427">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sales_info.csv to sales_info.csv

# %%
df = spark.read.csv('sales_info.csv',header=True,inferSchema=True)

# %%
df.show()
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |   GOOG|    Sam|200.0|
# |   GOOG|Charlie|120.0|
# |   GOOG|  Frank|340.0|
# |   MSFT|   Tina|600.0|
# |   MSFT|    Amy|124.0|
# |   MSFT|Vanessa|243.0|
# |     FB|   Carl|870.0|
# |     FB|  Sarah|350.0|
# |   APPL|   John|250.0|
# |   APPL|  Linda|130.0|
# |   APPL|   Mike|750.0|
# |   APPL|  Chris|350.0|
# +-------+-------+-----+

# %%
## group by operation the aggrating

df.groupBy('Company').mean().show()
# Out:
# +-------+-----------------+
# |Company|       avg(Sales)|
# +-------+-----------------+
# |   APPL|            370.0|
# |   GOOG|            220.0|
# |     FB|            610.0|
# |   MSFT|322.3333333333333|
# +-------+-----------------+

# %%
df.groupBy('Company').count().show()
# Out:
# +-------+-----+
# |Company|count|
# +-------+-----+
# |   APPL|    4|
# |   GOOG|    3|
# |     FB|    2|
# |   MSFT|    3|
# +-------+-----+

# %%
# Aggregating the data

df.agg({"Sales":"max"}).show()
# Out:
# +----------+
# |max(Sales)|
# +----------+
# |     870.0|
# +----------+

# %%
group_data = df.groupBy('Company')
group_data.agg({'Sales':'sum'}).show()
# Out:
# +-------+----------+
# |Company|sum(Sales)|
# +-------+----------+
# |   APPL|    1480.0|
# |   GOOG|     660.0|
# |     FB|    1220.0|
# |   MSFT|     967.0|
# +-------+----------+

# %%
## Import pyspark functions 

from pyspark.sql.functions import avg,countDistinct,stddev

# %%
df.select(countDistinct('Company')).show()
# Out:
# +-----------------------+
# |count(DISTINCT Company)|
# +-----------------------+
# |                      4|
# +-----------------------+

# %%
df.select(avg('Sales')).show()
# Out:
# +-----------------+
# |       avg(Sales)|
# +-----------------+
# |360.5833333333333|
# +-----------------+

# %%
df_dev=df.select(stddev('Sales').alias('STD dev Sales'))

# %%
## Import pyspark functions 

from pyspark.sql.functions import format_number

# %%
df_dev.select(format_number('STD dev Sales',2)).show()
# Out:
# +-------------------------------+
# |format_number(STD dev Sales, 2)|
# +-------------------------------+
# |                         250.09|
# +-------------------------------+

# %%
# Sort the data
df.orderBy('Sales').show()
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |   GOOG|Charlie|120.0|
# |   MSFT|    Amy|124.0|
# |   APPL|  Linda|130.0|
# |   GOOG|    Sam|200.0|
# |   MSFT|Vanessa|243.0|
# |   APPL|   John|250.0|
# |   GOOG|  Frank|340.0|
# |     FB|  Sarah|350.0|
# |   APPL|  Chris|350.0|
# |   MSFT|   Tina|600.0|
# |   APPL|   Mike|750.0|
# |     FB|   Carl|870.0|
# +-------+-------+-----+

# %%
df.orderBy(df['Sales'].desc()).show()
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |     FB|   Carl|870.0|
# |   APPL|   Mike|750.0|
# |   MSFT|   Tina|600.0|
# |     FB|  Sarah|350.0|
# |   APPL|  Chris|350.0|
# |   GOOG|  Frank|340.0|
# |   APPL|   John|250.0|
# |   MSFT|Vanessa|243.0|
# |   GOOG|    Sam|200.0|
# |   APPL|  Linda|130.0|
# |   MSFT|    Amy|124.0|
# |   GOOG|Charlie|120.0|
# +-------+-------+-----+

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9bd75784-1113-4644-8331-0228f46edccf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bd75784-1113-4644-8331-0228f46edccf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving appl_stock.csv to appl_stock.csv

# %%
#Date n time 
df = spark.read.csv('appl_stock.csv',header=True,inferSchema=True)
df.select(['Date','Open']).show()
# Out:
# +-------------------+------------------+
# |               Date|              Open|
# +-------------------+------------------+
# |2010-01-04 00:00:00|        213.429998|
# |2010-01-05 00:00:00|        214.599998|
# |2010-01-06 00:00:00|        214.379993|
# |2010-01-07 00:00:00|            211.75|
# |2010-01-08 00:00:00|        210.299994|
# |2010-01-11 00:00:00|212.79999700000002|
# |2010-01-12 00:00:00|209.18999499999998|
# |2010-01-13 00:00:00|        207.870005|
# |2010-01-14 00:00:00|210.11000299999998|
# |2010-01-15 00:00:00|210.92999500000002|
# |2010-01-19 00:00:00|        208.330002|
# |2010-01-20 00:00:00|        214.910006|
# |2010-01-21 00:00:00|        212.079994|
# |2010-01-22 00:00:00|206.78000600000001|
# |2010-01-25 00:00:00|202.51000200000001|
# |2010-01-26 00:00:00|205.95000100000001|
# |2010-01-27 00:00:00|        206.849995|
# |2010-01-28 00:00:00|        204.930004|
# |2010-01-29 00:00:00|        201.079996|
# |2010-02-01 00:00:00|192.36999699999998|
# +-------------------+------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import dayofyear, hour, month, year, weekofyear,format_number,date_format

# %%
#df.select(year('Date')).show()
#df.select(month('Date')).show()
df.select(dayofyear('Date')).show()
# Out:
# +---------------+
# |dayofyear(Date)|
# +---------------+
# |              4|
# |              5|
# |              6|
# |              7|
# |              8|
# |             11|
# |             12|
# |             13|
# |             14|
# |             15|
# |             19|
# |             20|
# |             21|
# |             22|
# |             25|
# |             26|
# |             27|
# |             28|
# |             29|
# |             32|
# +---------------+
# only showing top 20 rows

# %%
newdf = df.withColumn("Year",year(df['Date']))
newdf.show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+----+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|Year|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+----+
# |2010-01-04 00:00:00|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|2010|
# |2010-01-05 00:00:00|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|2010|
# |2010-01-06 00:00:00|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|2010|
# |2010-01-07 00:00:00|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|2010|
# |2010-01-08 00:00:00|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|2010|
# |2010-01-11 00:00:00|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|2010|
# |2010-01-12 00:00:00|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|2010|
# |2010-01-13 00:00:00|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|2010|
# |2010-01-14 00:00:00|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|2010|
# |2010-01-15 00:00:00|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|2010|
# |2010-01-19 00:00:00|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|2010|
# |2010-01-20 00:00:00|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|2010|
# |2010-01-21 00:00:00|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|2010|
# |2010-01-22 00:00:00|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|2010|
# |2010-01-25 00:00:00|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|2010|
# |2010-01-26 00:00:00|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|2010|
# |2010-01-27 00:00:00|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|2010|
# |2010-01-28 00:00:00|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|2010|
# |2010-01-29 00:00:00|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|2010|
# |2010-02-01 00:00:00|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|2010|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+----+
# only showing top 20 rows

# %%
result = newdf.groupBy('Year').mean().select(['Year','avg(Close)'])

# %%
new = result.withColumnRenamed('avg(Close)','Average Closing Price')
new.show()
# Out:
# +----+---------------------+
# |Year|Average Closing Price|
# +----+---------------------+
# |2015|   120.03999980555547|
# |2013|    472.6348802857143|
# |2014|    295.4023416507935|
# |2012|    576.0497195640002|
# |2016|   104.60400786904763|
# |2010|    259.8424600000002|
# |2011|   364.00432532142867|
# +----+---------------------+

# %%
new.select(['Year',format_number('Average Closing Price',2).alias('Avg Close')]).show()
# Out:
# +----+---------+
# |Year|Avg Close|
# +----+---------+
# |2015|   120.04|
# |2013|   472.63|
# |2014|   295.40|
# |2012|   576.05|
# |2016|   104.60|
# |2010|   259.84|
# |2011|   364.00|
# +----+---------+
